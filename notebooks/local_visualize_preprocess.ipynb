# %%
#@title Setup project root

PROJECT_ROOT = "/Users/yunfanbao/Documents/work/mv-mammo-transformer"

import os, sys

os.chdir(PROJECT_ROOT)
sys.path.append(PROJECT_ROOT)

print("Current directory:", os.getcwd())

# %%
# %matplotlib notebook

# %%
#@title Visualize preprocess flow

# %run -m scripts.visualize_preprocess -- --study-id 2e59c9d87903cf06b7c1d42fa0bb744c --laterality L --view-position MLO

# %%
#@title Visualize image samples

# %run -m scripts.visualize_preprocess -- --from-preprocessed
